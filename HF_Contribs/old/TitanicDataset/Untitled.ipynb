# %%
import pandas as pd 
import numpy as np

# %%
dftrain=pd.read_csv("train.csv")

# %%
dftest=pd.read_csv("test.csv")

# %%
dftrain.head()
# Out:
#    id        f0        f1        f2        f3        f4        f5        f6  \
# 0   0  0.205979  0.410993  0.176775  0.223581  0.423543  0.476140  0.413590
# 1   1  0.181004  0.473119  0.011734  0.213657  0.619678  0.441593  0.230407
# 2   2  0.182583  0.307431  0.325950  0.207116  0.605699  0.309695  0.493337
# 3   3  0.180240  0.494592  0.008367  0.223580  0.760618  0.439211  0.432055
# 4   4  0.177172  0.495513  0.014263  0.548819  0.625396  0.562493  0.117158
#
#          f7        f8  ...  f276  f277  f278  f279  f280  f281  f282  f283  \
# 0  0.612021  0.534873  ...     0     1     0     0     0     0     0     0
# 1  0.686013  0.281971  ...     0     1     0     0     0     0     0     0
# 2  0.751107  0.536272  ...     0     0     0     1     1     0     0     0
# 3  0.776147  0.483958  ...     0     0     0     0     1     0     0     0
# 4  0.561255  0.077115  ...     0     1     1     0     1     0     0     1
#
#    f284  target
# 0     0       1
# 1     0       1
# ...

# %%
dftrain.shape
# Out:
# (1000000, 287)

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Columns: 287 entries, id to target
# dtypes: float64(240), int64(47)
# memory usage: 2.1 GB

# %%
dftrain.isnull().sum()
# Out:
# id        0
# f0        0
# f1        0
# f2        0
# f3        0
#          ..
# f281      0
# f282      0
# f283      0
# f284      0
# target    0
# Length: 287, dtype: int64

# %%
dftrain.describe()
# Out:
#                    id              f0              f1              f2  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean    499999.500000        0.214334        0.460218        0.129253
# std     288675.278933        0.053320        0.101316        0.120805
# min          0.000000        0.041790        0.022016        0.000381
# 25%     249999.750000        0.181676        0.389215        0.017692
# 50%     499999.500000        0.204498        0.453893        0.095496
# 75%     749999.250000        0.229684        0.526023        0.177717
# max     999999.000000        1.000000        0.959019        0.994818
#
#                    f3              f4              f5              f6  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.277598        0.580710        0.416619        0.386532
# std          0.063163        0.115338        0.058231        0.133457
# ...

# %%
Y=dftrain['target']

# %%
dftrain.drop('target',inplace=True,axis=1)

# %%
dftrain.drop("id",inplace=True,axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train, Y_test = train_test_split(dftrain, Y, test_size=0.00000001,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
#StandardScaler
sc2=StandardScaler()
sc2.fit(X_train)
X_train2=sc2.transform(X_train)
X_test2=sc2.transform(X_test)
Y_train2=Y_train
Y_test2=Y_test

# %%
from sklearn.linear_model import SGDClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rn=RandomForestClassifier(max_depth=2, random_state=0)

# %%
 rn.fit(X_train2,Y_train2)

# %%
 sgc=SGDClassifier(max_iter=100000, tol=1e-5)

# %%
sgc.fit(X_train2,Y_train2)
# Out:
# SGDClassifier(max_iter=100000, tol=1e-05)

# %%
sgc.score(X_test2,Y_test2)
# Out:
# 0.0

# %%
dftest
# Out:
#              id        f0        f1        f2        f3        f4        f5  \
# 0       1000000  0.178216  0.435617  0.010230  0.202074  0.390170  0.324221
# 1       1000001  0.181250  0.476455  0.022413  0.283146  0.598020  0.349508
# 2       1000002  0.159721  0.451202  0.259649  0.365274  0.594634  0.413502
# 3       1000003  0.182424  0.520976  0.095344  0.327742  0.741830  0.358711
# 4       1000004  0.229329  0.336513  0.023511  0.300913  0.668738  0.481586
# ...         ...       ...       ...       ...       ...       ...       ...
# 499995  1499995  0.185473  0.525338  0.014945  0.204029  0.498957  0.431933
# 499996  1499996  0.183194  0.553266  0.008055  0.280651  0.636591  0.478092
# 499997  1499997  0.184650  0.533643  0.011218  0.201262  0.720698  0.472888
# 499998  1499998  0.227731  0.513247  0.178603  0.313778  0.665656  0.401365
# 499999  1499999  0.185561  0.406225  0.097598  0.327129  0.655168  0.384097
#
# ...

# %%
dftest1=dftest
df=dftest1[['id']]
dftest1.drop('id',inplace=True, axis=1)

# %%
X=dftest1.to_numpy()

# %%
sc=StandardScaler()
sc.fit(X)

# %%
xpredict=sc.transform(X)

# %%
ypredict=rn.predict(xpredict)

# %%
ypredict.shape

# %%
df['target']=ypredict

# %%
df

# %%
df.to_csv('file.csv', header=True, index=False)
